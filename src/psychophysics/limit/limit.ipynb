# %%
import glob
import csv

# You can try the 'method of limit' from the link below:
# https://shigeodayo.github.io/PsychophysicsWebExp/index.html
CSV_PATH = '../../../data/psychophysics/limit'  # Put the experimental data (CSVs) in this directory.
HALF_STEP = 0.5  # the half of the step to increase/decrease the lightness, the unit is '%'

def main():
    answer_csvs = glob.glob(CSV_PATH + '/*.csv')
    print('num of csvs: {}'.format(len(answer_csvs)))

    part_avg_ans_up = [0] * len(answer_csvs)
    part_avg_ans_down = [0] * len(answer_csvs)
    part_avg_ans = [0] * len(answer_csvs)
    for i, answer_csv in enumerate(answer_csvs):
        id, part_avg_ans_up[i], part_avg_ans_down[i] = get_avg_ans(answer_csv)
        part_avg_ans[i] = (part_avg_ans_up[i] + part_avg_ans_down[i]) / 2
        print('{} (avg): {:.2f} (up) - {:.2f} (down)'.format(id, part_avg_ans_up[i], part_avg_ans_down[i]))

    print('------------------------------------------------')
    print('PSE = {:.2f}%'.format(sum(part_avg_ans) / len(part_avg_ans)))
    print('------------------------------------------------')


def get_avg_ans(answer_csv):
    with open(answer_csv) as f:
        reader = csv.reader(f)
        lines = [row for row in reader]
        id = lines[0][1]
        sum_up = 0
        sum_down = 0
        # print(lines[2])
        for i in range(len(lines[1])):
            if lines[1][i] == 'up':
                sum_up += int(lines[2][i]) - HALF_STEP
            else:
                sum_down += int(lines[2][i]) + HALF_STEP
        return id, (sum_up / lines[1].count('up')), (sum_down / lines[1].count('down'))


if __name__ == '__main__':
    main()
# Out:
# num of csvs: 98
# sy_ifobtx (avg): 29.50 (up) - 68.00 (down)
# sy_67m73z (avg): 41.50 (up) - 54.50 (down)
# sy_g7gtn2 (avg): 13.00 (up) - 45.50 (down)
# sy_hlqj1q (avg): 30.00 (up) - 67.00 (down)
# sy_br3x14 (avg): 22.00 (up) - 77.00 (down)
# sy_x2r6fn (avg): 39.00 (up) - 46.00 (down)
# sy_5077ur (avg): 40.00 (up) - 49.50 (down)
# sy_4jzumt (avg): 35.50 (up) - 82.00 (down)
# sy_31uw41 (avg): 30.50 (up) - 74.00 (down)
# sy_fgzfd5 (avg): 46.50 (up) - 49.00 (down)
# sy_k7qrcj (avg): 42.00 (up) - 62.50 (down)
# sy_cynyag (avg): 17.00 (up) - 78.00 (down)
# sy_3eglhj (avg): 31.50 (up) - 72.00 (down)
# sy_ulmaqa (avg): 28.50 (up) - 46.00 (down)
# sy_03kefq (avg): 26.50 (up) - 69.50 (down)
# sy_qepomh (avg): 37.00 (up) - 45.50 (down)
# sy_twemgr (avg): 41.50 (up) - 68.50 (down)
# sy_6u05f0 (avg): 47.00 (up) - 53.50 (down)
# sy_hl9slr (avg): 39.50 (up) - 44.00 (down)
# sy_ko4atk (avg): 37.50 (up) - 43.50 (down)
# sy_0s02if (avg): 44.50 (up) - 65.50 (down)
# sy_8ttvup (avg): 46.50 (up) - 51.50 (down)
# sy_15f5si (avg): 38.00 (up) - 47.50 (down)
# sy_2yhyfk (avg): 33.50 (up) - 43.00 (down)
# sy_x8r3dg (avg): 31.50 (up) - 74.50 (down)
# sy_wvwedk (avg): 9.00 (up) - 74.00 (down)
# sy_el0iaz (avg): 37.00 (up) - 73.00 (down)
# sy_2nlcqm (avg): 26.00 (up) - 74.00 (down)
# sy_olek6s (avg): 21.00 (up) - 65.00 (down)
# sy_05y8lr (avg): 37.00 (up) - 56.50 (down)
# sy_fcdxfo (avg): 28.00 (up) - 52.00 (down)
# sy_x0ditf (avg): 43.50 (up) - 70.50 (down)
# sy_haavbf (avg): 26.00 (up) - 67.50 (down)
# sy_27iqv6 (avg): 35.00 (up) - 41.00 (down)
# sy_0b2uq9 (avg): 26.50 (up) - 74.00 (down)
# sy_gvjj3l (avg): 40.00 (up) - 48.00 (down)
# sy_vut07b (avg): 61.00 (up) - 60.50 (down)
# sy_p9kpls (avg): 50.50 (up) - 71.50 (down)
# sy_s3uizm (avg): 36.50 (up) - 58.00 (down)
# sy_4qvibv (avg): 40.50 (up) - 71.00 (down)
# sy_cexpir (avg): 34.00 (up) - 69.50 (down)
# sy_c6e46i (avg): 45.50 (up) - 48.00 (down)
# sy_1lguet (avg): 24.50 (up) - 47.00 (down)
# sy_2azwg0 (avg): 30.50 (up) - 55.00 (down)
# sy_ej46kf (avg): 44.00 (up) - 66.50 (down)
# sy_5bkvd5 (avg): 46.00 (up) - 59.00 (down)
# sy_sv05p8 (avg): 36.00 (up) - 44.50 (down)
# sy_r2agx9 (avg): 0.50 (up) - 90.00 (down)
# sy_a4nt38 (avg): 34.50 (up) - 73.50 (down)
# sy_m0vxf0 (avg): 45.50 (up) - 51.00 (down)
# sy_7iy98i (avg): 21.50 (up) - 64.00 (down)
# sy_grdfxp (avg): 29.50 (up) - 40.50 (down)
# sy_ypasc7 (avg): 39.00 (up) - 46.00 (down)
# sy_eagf0o (avg): 41.50 (up) - 45.00 (down)
# sy_jzbppj (avg): 53.50 (up) - 57.00 (down)
# sy_a10bys (avg): 27.50 (up) - 74.00 (down)
# sy_khi8ww (avg): 46.50 (up) - 66.50 (down)
# sy_anb1d3 (avg): 31.00 (up) - 56.00 (down)
# sy_wdg30q (avg): 37.00 (up) - 68.50 (down)
# sy_fmmtqy (avg): 57.50 (up) - 66.00 (down)
# sy_rbrb06 (avg): 32.00 (up) - 67.50 (down)
# sy_omzyy8 (avg): 38.50 (up) - 45.00 (down)
# sy_qfdjcm (avg): 41.00 (up) - 53.50 (down)
# sy_pig7yh (avg): 40.50 (up) - 59.00 (down)
# sy_4cph4z (avg): 42.50 (up) - 52.50 (down)
# sy_89qde9 (avg): 50.50 (up) - 65.50 (down)
# sy_q7au79 (avg): 31.50 (up) - 56.00 (down)
# sy_2uw09g (avg): 38.50 (up) - 63.50 (down)
# sy_n8u9pv (avg): 46.50 (up) - 56.50 (down)
# sy_5ss5z1 (avg): 35.50 (up) - 46.00 (down)
# sy_dpohez (avg): 41.00 (up) - 57.50 (down)
# sy_p4s37j (avg): 45.00 (up) - 74.00 (down)
# sy_jd8hb1 (avg): 43.00 (up) - 79.00 (down)
# sy_l51ywy (avg): 40.00 (up) - 70.00 (down)
# sy_0e7iq7 (avg): 36.00 (up) - 68.00 (down)
# sy_t4o261 (avg): 33.50 (up) - 55.50 (down)
# sy_4fpv6v (avg): 34.50 (up) - 65.00 (down)
# sy_bfh7cv (avg): 34.50 (up) - 50.00 (down)
# sy_8u7xs4 (avg): 20.50 (up) - 56.00 (down)
# sy_fxjxrg (avg): 32.50 (up) - 39.50 (down)
# sy_i9bs4h (avg): 31.00 (up) - 59.00 (down)
# sy_k98qj0 (avg): 55.00 (up) - 71.00 (down)
# sy_jmopag (avg): 35.50 (up) - 44.50 (down)
# sy_fm3ojq (avg): 22.50 (up) - 80.50 (down)
# sy_y2g5pk (avg): 16.00 (up) - 69.00 (down)
# sy_h0zxp8 (avg): 42.50 (up) - 60.50 (down)
# sy_5v5eob (avg): 21.00 (up) - 73.50 (down)
# sy_f60c91 (avg): 20.00 (up) - 73.50 (down)
# sy_frar9f (avg): 48.50 (up) - 70.50 (down)
# sy_dwf6vp (avg): 39.50 (up) - 60.00 (down)
# sy_lwjvk7 (avg): 38.50 (up) - 69.00 (down)
# sy_n180a4 (avg): 33.50 (up) - 45.50 (down)
# sy_mnrd5y (avg): 39.50 (up) - 62.50 (down)
# sy_djjl1z (avg): 32.50 (up) - 40.50 (down)
# sy_mc833m (avg): 28.50 (up) - 61.50 (down)
# sy_ndmstn (avg): 1.00 (up) - 97.00 (down)
# sy_c8igmh (avg): 22.50 (up) - 78.00 (down)
# sy_zzktg6 (avg): 33.50 (up) - 87.50 (down)
# ------------------------------------------------
# PSE = 48.14%
# ------------------------------------------------
